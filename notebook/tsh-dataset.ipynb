# %%
import pandas as pd

# %%
data1 = pd.read_csv('Precipitation amount during wettest days tsh.csv')
data2 = pd.read_csv('Relative Humidity tsh.csv')
data3 = pd.read_csv('Temperature-based Excess Mortality tsh.csv')
data4 = pd.read_csv('Annual SPEI Drought Index tsh.csv')
data5 = pd.read_csv('Average Mean Surface Air Temperature tsh.csv')
data6 = pd.read_csv('Average Minimum Surface Air Temperature tsh.csv')
data7 = pd.read_csv('Average Maximum Surface Air Temperature tsh.csv')
data8 = pd.read_csv('Precipitation tsh.csv')
data9 = pd.read_csv('Average Largest 5-Day Cumulative Precipitation tsh.csv')
data10 = pd.read_csv('Average Largest 1-Day Precipitation tsh (2).csv')

# %%
data_result = pd.concat([data5,data6,data7,data8], axis=1)

# %%
data_result2 = pd.concat([data1,data2,data3,data4,data9,data10], axis=1)

# %%
#data = pd.concat([data_result,data_result2],axis=1)
#data
data_result = data_result.loc[:, ~data_result.columns.duplicated()]
data_result
# Out:
#      Category  Average Mean Surface Air Temperature (Annual Mean °C)  \
# 0        1901                                              14.65
# 1        1902                                              15.35
# 2        1903                                              13.78
# 3        1904                                              14.33
# 4        1905                                              14.07
# ..        ...                                                ...
# 119      2020                                              15.80
# 120      2021                                              16.91
# 121      2022                                              17.14
# 122      2023                                              17.70
# 123      2024                                              16.84
#
#      5-year smooth (Gaussian Smooth)  \
# 0                              14.87
# 1                              14.64
# 2                              14.44
# ...

# %%
data_result2 = data_result2.loc[:, ~data_result2.columns.duplicated()]
data_result2
# Out:
#     Category  Precipitation amount during wettest days (mm)  \
# 0       1950                                           5.79
# 1       1951                                          20.58
# 2       1952                                          23.52
# 3       1953                                          20.94
# 4       1954                                          22.22
# ..       ...                                            ...
# 70      2020                                          24.32
# 71      2021                                           6.21
# 72      2022                                          27.28
# 73      2023                                          19.39
# 74      2024                                          25.91
#
#     Relative Humidity (%)  Temperature-based Excess Mortality (factor)  \
# 0                   51.42                                         0.09
# 1                   60.51                                         0.06
# ...

# %%
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 6 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Category                                                  124 non-null    int64
#  1   Average Mean Surface Air Temperature (Annual Mean °C)     124 non-null    float64
#  2   5-year smooth (Gaussian Smooth)                           124 non-null    float64
#  3   Average Minimum Surface Air Temperature (Annual Mean °C)  124 non-null    float64
#  4   Average Maximum Surface Air Temperature (Annual Mean °C)  124 non-null    float64
#  5   Precipitation (Annual Mean mm)                            124 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 5.9 KB

# %%
data_result2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 7 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Category                                             75 non-null     int64
#  1   Precipitation amount during wettest days (mm)        75 non-null     float64
#  2   Relative Humidity (%)                                75 non-null     float64
#  3   Temperature-based Excess Mortality (factor)          75 non-null     float64
#  4   Annual SPEI Drought Index (spei index)               74 non-null     float64
#  5   Average Largest 5-Day Cumulative Precipitation (mm)  75 non-null     float64
#  6   Average Largest 1-Day Precipitation (mm)             75 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 4.2 KB

# %%
data_result2.isnull().sum()
# Out:
# Category                                               0
# Precipitation amount during wettest days (mm)          0
# Relative Humidity (%)                                  0
# Temperature-based Excess Mortality (factor)            0
# Annual SPEI Drought Index (spei index)                 1
# Average Largest 5-Day Cumulative Precipitation (mm)    0
# Average Largest 1-Day Precipitation (mm)               0
# dtype: int64

# %%
data_result2[data_result2.isnull().any(axis=1)]
# Out:
#    Category  Precipitation amount during wettest days (mm)  \
# 0      1950                                           5.79
#
#    Relative Humidity (%)  Temperature-based Excess Mortality (factor)  \
# 0                  51.42                                         0.09
#
#    Annual SPEI Drought Index (spei index)  \
# 0                                     NaN
#
#    Average Largest 5-Day Cumulative Precipitation (mm)  \
# 0                                              56.57
#
#    Average Largest 1-Day Precipitation (mm)
# 0                                     18.03

# %%
data_result2['Annual SPEI Drought Index (spei index)'].mean()
# Out:
# np.float64(-0.05635135135135137)

# %%
data_result2['Annual SPEI Drought Index (spei index)'] = data_result2['Annual SPEI Drought Index (spei index)'].fillna(data_result2['Annual SPEI Drought Index (spei index)'].mean())
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_26672\1568186685.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_result2['Annual SPEI Drought Index (spei index)'].head()
# Out:
# 0   -0.056351
# 1   -0.820000
# 2    0.630000
# 3    0.350000
# 4    1.250000
# Name: Annual SPEI Drought Index (spei index), dtype: float64

# %%
data_result2.isnull().sum()
# Out:
# Category                                               0
# Precipitation amount during wettest days (mm)          0
# Relative Humidity (%)                                  0
# Temperature-based Excess Mortality (factor)            0
# Annual SPEI Drought Index (spei index)                 0
# Average Largest 5-Day Cumulative Precipitation (mm)    0
# Average Largest 1-Day Precipitation (mm)               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data_result['Category']
# Out:
# 0      1901
# 1      1902
# 2      1903
# 3      1904
# 4      1905
#        ...
# 119    2020
# 120    2021
# 121    2022
# 122    2023
# 123    2024
# Name: Category, Length: 124, dtype: int64

# %%
data_result.head(2)
# Out:
#    Category  Average Mean Surface Air Temperature (Annual Mean °C)  \
# 0      1901                                              14.65
# 1      1902                                              15.35
#
#    5-year smooth (Gaussian Smooth)  \
# 0                            14.87
# 1                            14.64
#
#    Average Minimum Surface Air Temperature (Annual Mean °C)  \
# 0                                               7.81
# 1                                               8.52
#
#    Average Maximum Surface Air Temperature (Annual Mean °C)  \
# 0                                              21.53
# 1                                              22.21
#
#    Precipitation (Annual Mean mm)
# 0                           544.5
# 1                           714.3

# %%
data_result = data_result.rename(columns={'Category':'Year'})
import plotly.express as px
parametr = [
    'Average Maximum Surface Air Temperature (Annual Mean °C)',
    '5-year smooth (Gaussian Smooth)',
    'Average Mean Surface Air Temperature (Annual Mean °C)',
    'Average Minimum Surface Air Temperature (Annual Mean °C)',
    'Precipitation (mm)'
]
for d in parametr:
    fig = px.line(data_result, x='Year', y=d)
    fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 11
#       3 parametr = [
#       4     'Average Maximum Surface Air Temperature (Annual Mean °C)',
#       5     '5-year smooth (Gaussian Smooth)',
#    (...)
#       8     'Precipitation (mm)'
#       9 ]
#      10 for d in parametr:
# ---> 11     fig = px.line(data_result, x='Year', y=d)
#      12     fig.show()
#
# ...

# %%
data_result2.head(2)
# Out:
#    Category  Precipitation amount during wettest days (mm)  \
# 0      1950                                           5.79
# 1      1951                                          20.58
#
#    Relative Humidity (%)  Temperature-based Excess Mortality (factor)  \
# 0                  51.42                                         0.09
# 1                  60.51                                         0.06
#
#    Annual SPEI Drought Index (spei index)  \
# 0                               -0.056351
# 1                               -0.820000
#
#    Average Largest 5-Day Cumulative Precipitation (mm)  \
# 0                                              56.57
# 1                                              60.60
#
#    Average Largest 1-Day Precipitation (mm)
# 0                                     18.03
# 1                                     27.25

# %%
data_result2 = data_result2.rename(columns={'Category':'Year'})
parametrs = [
    'Annual SPEI Drought Index (spei index)',
    'Average Largest 1-Day Precipitation (mm)',
    'Average Largest 5-Day Cumulative Precipitation (mm)',
    'Precipitation amount during wettest days (mm)',
    'Relative Humidity (%)',
    'Temperature-based Excess Mortality (factor)'
]
for d in parametrs:
    fig = px.line(data_result2, x='Year', y=d)
    fig.show()

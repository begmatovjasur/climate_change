# %%
import pandas as pd

# %%
df1 = pd.read_csv('Annual SPEI Drought Index nam.csv')
df2 = pd.read_csv('Average Largest 1-Day Precipitation nam.csv')
df3 = pd.read_csv('Average Largest 5-Day Cumulative Precipitation nam.csv')
df4 = pd.read_csv('nam-max-observed-timeseries-of-a (13).csv')
df5 = pd.read_csv('nam-mean-observed-timeseries-of-a (13).csv')
df6 = pd.read_csv('nam-min-observed-timeseries-of-a (13).csv')
df7 = pd.read_csv('nam-precipitation-observed-timeseries-of-a (13).csv')
df8 = pd.read_csv('Precipitation amount during wettest days nam.csv')
df9 = pd.read_csv('Relative Humidity nam.csv')
df10 = pd.read_csv('Temperature-based Excess Mortality nam.csv')

# %%
data1 = pd.concat([df4,df5,df6,df7], axis=1)
data1 = data1.loc[:, ~data1.columns.duplicated()]

# %%
data2 = pd.concat([df1,df2,df3,df8,df9,df10], axis=1)
data2 = data2.loc[:, ~data2.columns.duplicated()]
data2
# Out:
#     Category  Annual SPEI Drought Index (spei index)  \
# 0       1950                                     NaN
# 1       1951                                   -0.12
# 2       1952                                    0.58
# 3       1953                                    0.01
# 4       1954                                    1.41
# ..       ...                                     ...
# 70      2020                                   -0.37
# 71      2021                                   -0.37
# 72      2022                                   -0.50
# 73      2023                                   -0.57
# 74      2024                                   -0.49
#
#     Average Largest 1-Day Precipitation (mm)  \
# 0                                      16.67
# 1                                      16.60
# 2                                      20.06
# 3                                      20.18
# 4                                      19.73
# ..                                       ...
# 70                                     17.66
# 71                                     20.30
# 72                                     25.33
# 73                                     21.58
# 74                                     35.84
#
#     Average Largest 5-Day Cumulative Precipitation (mm)  \
# 0                                               48.67
# 1                                               47.59
# 2                                               42.73
# 3                                               45.01
# 4                                               68.41
# ..                                                ...
# 70                                              45.35
# 71                                              44.81
# 72                                              62.76
# 73                                              54.86
# 74                                              66.35
#
#     Precipitation amount during wettest days (mm)  Relative Humidity (%)  \
# 0                                            6.31                  51.95
# 1                                            4.90                  57.17
# 2                                            9.17                  53.92
# 3                                           10.47                  55.63
# 4                                            7.94                  56.14
# ..                                            ...                    ...
# 70                                           6.52                  54.71
# 71                                          12.88                  50.89
# 72                                           7.01                  53.81
# 73                                          15.49                  52.27
# 74                                          17.52                  57.74
#
#     Temperature-based Excess Mortality (factor)
# 0                                          0.06
# 1                                          0.03
# 2                                          0.05
# 3                                          0.07
# 4                                          0.01
# ..                                          ...
# 70                                         0.05
# 71                                         0.09
# 72                                         0.17
# 73                                         0.15
# 74                                         0.10
#
# [75 rows x 7 columns]

# %%
data2['Annual SPEI Drought Index (spei index)'] = data2['Annual SPEI Drought Index (spei index)'].fillna(data2['Annual SPEI Drought Index (spei index)'].mean())

# %%
data2.isnull().sum()
# Out:
# Category                                               0
# Annual SPEI Drought Index (spei index)                 0
# Average Largest 1-Day Precipitation (mm)               0
# Average Largest 5-Day Cumulative Precipitation (mm)    0
# Precipitation amount during wettest days (mm)          0
# Relative Humidity (%)                                  0
# Temperature-based Excess Mortality (factor)            0
# dtype: int64

# %%
data1 = data1.rename(columns={'Category':'Year'})

# %%
data1.head(2)
# Out:
#    Year  Average Maximum Surface Air Temperature (Annual Mean °C)  \
# 0  1901                                              16.24
# 1  1902                                              17.08
#
#    5-year smooth (Gaussian Smooth)  \
# 0                            16.50
# 1                            16.29
#
#    Average Mean Surface Air Temperature (Annual Mean °C)  \
# 0                                               9.65
# 1                                              10.49
#
#    Average Minimum Surface Air Temperature (Annual Mean °C)  \
# 0                                               3.08
# 1                                               3.94
#
#    Precipitation (Annual Mean mm)
# 0                          571.77
# 1                          706.77

# %%
import plotly.express as px
parametr = [
    'Average Maximum Surface Air Temperature (Annual Mean °C)',
    '5-year smooth (Gaussian Smooth)',
    'Average Mean Surface Air Temperature (Annual Mean °C)',
    'Average Minimum Surface Air Temperature (Annual Mean °C)',
    'Precipitation (Annual Mean mm)'
]
for d in parametr:
    fig = px.line(data1, x='Year', y=d)
    fig.show()

# %%
data2 = data2.rename(columns={'Category':'Year'})

# %%
data2.head(2)
# Out:
#    Year  Annual SPEI Drought Index (spei index)  \
# 0  1950                                0.010946
# 1  1951                               -0.120000
#
#    Average Largest 1-Day Precipitation (mm)  \
# 0                                     16.67
# 1                                     16.60
#
#    Average Largest 5-Day Cumulative Precipitation (mm)  \
# 0                                              48.67
# 1                                              47.59
#
#    Precipitation amount during wettest days (mm)  Relative Humidity (%)  \
# 0                                           6.31                  51.95
# 1                                           4.90                  57.17
#
#    Temperature-based Excess Mortality (factor)
# 0                                         0.06
# 1                                         0.03

# %%
parametrs = [
    'Annual SPEI Drought Index (spei index)',
    'Average Largest 1-Day Precipitation (mm)',
    'Average Largest 5-Day Cumulative Precipitation (mm)',
    'Precipitation amount during wettest days (mm)',
    'Relative Humidity (%)',
    'Temperature-based Excess Mortality (factor)'
]
for d in parametrs:
    fig = px.line(data2, x='Year', y=d)
    fig.show()
